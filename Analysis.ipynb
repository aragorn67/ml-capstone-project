# %% [markdown]
# # BBO Capstone — Black-Box Optimisation Challenge
#
# **Weekly workflow:**
# 1. Update `new_data` (Cell 2) with last week's results
# 2. Adjust `FUNCTION_CONFIG` (Cell 1) if changing strategy
# 3. Run all cells
# 4. Copy portal strings, submit

# %% [markdown]
# ## Config

# %%
import sys
sys.path.insert(0, '.')  # ensure bbo package is importable
from bbo import generate_all_queries

# ============================================================
# PATH TO DATA
# ============================================================
BASE_PATH = "Initial_data_points_starter/initial_data"

# ============================================================
# PER-FUNCTION STRATEGY CONFIGURATION
# ============================================================
# 
# Available strategies: "gp_ei", "gp_ucb", "lhs"
#
# Parameters:
#   strategy:    "gp_ei" | "gp_ucb" | "lhs"
#   xi:          EI exploration (0.01=exploit, 0.1=explore)
#   kappa:       UCB exploration (0.5=exploit, 2.0=explore)
#   n_restarts:  search budget (higher dims need more)
#   exploit_std: perturbation noise for exploitation restarts
#                (0.05=standard, 0.01=tight, 0.15=loose)
#   kernel_nu:   Matern smoothness (0.5=rough, 1.5=medium, 2.5=smooth)
#   alpha:       GP noise term (1e-6=noiseless, 1e-2=noisy)
# ============================================================
FUNCTION_CONFIG = {
    1: {"strategy": "gp_ucb", "kappa": 0.5, "n_restarts": 100,
        "exploit_std": 0.01, "kernel_nu": 0.5, "alpha": 1e-4},
        # On the peak. Final squeeze.

    2: {"strategy": "ensemble", "alpha": 0.1},
        # Noisy. Best we can do is query near (0.690, 0.999).

    3: {"strategy": "ensemble", "kernel_nu": 0.5},
        # Exploit -0.008 point. Last chance.

    4: {"strategy": "gp_ucb", "kappa": 0.5, "n_restarts": 100,
        "exploit_std": 0.03},
        # Never-ending climb. One more.

    5: {"strategy": "gp_ucb", "kappa": 0.5, "n_restarts": 100},
        # Done — but submit 0.999999 manually for max precision.

    6: {"strategy": "gp_ucb", "kappa": 0.3, "n_restarts": 200,
        "exploit_std": 0.02},
        # Exploit around -0.178 point.

    7: {"strategy": "ensemble"},
        # Seven consecutive improvements. Let it ride.

    8: {"strategy": "ensemble", "alpha": 1e-4},
        # Near peak. Final probe.
}

# %% [markdown]
# ## Weekly data
#
# Add each week's results here. Format: `([x1, x2, ...], output),`

# %%
new_data = {
    1: [
        ([0.785176, 0.785690], 1.2351102344508783e-34),
        ([0.018180, 0.922600], -1.0055210918914038e-288),
        ([0.448991, 0.452005], 0.010342219496741753),
        ([0.004862, 0.049606], 8.073651712927298e-218),
        ([0.452771, 0.480044], -0.00018764063934138922),
        ([0.439176, 0.452015], 0.03524285555637831),
        ([0.439114, 0.452015], 0.03544179990090668),
        ([0.450746, 0.452015], 0.007560838376711595),
        ([0.439023, 0.452015], 0.03573435129971763),
        ([0.438900, 0.453552], 0.025677652644779825),
        ([0.438908, 0.451982], 0.03635311534409354),
        ([0.438746, 0.451940], 0.03720238916216493),
    ],
    2: [
        ([0.734601, 0.802874], 0.4724027836292995),
        ([0.697610, 0.239403], 0.5006022660741053),
        ([0.675657, 0.999000], 0.6670258011155928),
        ([0.989338, 0.999000], -0.10052593298473093),
        ([0.734598, 0.802871], 0.665902512174246),
        ([0.734595, 0.802868], 0.5986022743429449),
        ([0.734598, 0.802869], 0.43423369841406134),
        ([0.687170, 0.999000], 0.5779953964478798),
        ([0.689878, 0.999000], 0.7623609921422494),
        ([0.689126, 0.999000], 0.6246678712868166),
        ([0.689504, 0.999000], 0.62248536484546),
        ([0.689787, 0.999000], 0.527550486929153),
    ],
    3: [
        ([0.245858, 0.389517, 0.303245], -0.07096556525123528),
        ([0.521435, 0.375727, 0.358734], -0.027526073585034744),
        ([0.482736, 0.194799, 0.001000], -0.14798002938939386),
        ([0.581496, 0.746896, 0.256784], -0.11292619823898144),
        ([0.598819, 0.999000, 0.393625], -0.06121650032784162),
        ([0.945223, 0.999000, 0.355389], -0.0675132120113626),
        ([0.005622, 0.494532, 0.397164], -0.02442514001649473),
        ([0.001000, 0.001000, 0.401624], -0.08715181483872689),
        ([0.521435, 0.375727, 0.358734], -0.03393248614740273),
        ([0.001008, 0.518377, 0.396576], -0.007756152811815391),
        ([0.001000, 0.259500, 0.276500], -0.11706831781469174),
        ([0.001000, 0.541000, 0.396000], -0.018929498915373152),
    ],
    4: [
        ([0.440428, 0.425455, 0.378357, 0.397087], 0.2596004445905611),
        ([0.409546, 0.415969, 0.347842, 0.437665], 0.4595649284592018),
        ([0.399230, 0.415268, 0.370997, 0.434186], 0.4709906450099841),
        ([0.425777, 0.364754, 0.370254, 0.440619], 0.4063947747891743),
        ([0.405808, 0.394119, 0.361314, 0.427372], 0.5453625301726004),
        ([0.397234, 0.389165, 0.354756, 0.416770], 0.49786839443353204),
        ([0.408518, 0.393476, 0.363296, 0.428397], 0.5441139656431848),
        ([0.410020, 0.393565, 0.364040, 0.428826], 0.546482308244745),
        ([0.411078, 0.393695, 0.364406, 0.429069], 0.5492086741201416),
        ([0.412038, 0.393836, 0.364610, 0.429256], 0.5523281777041409),
        ([0.413100, 0.393997, 0.364661, 0.429425], 0.5565566075084054),
        ([0.414523, 0.394192, 0.364468, 0.429596], 0.5629020608482702),
    ],
    5: [
        ([0.651987, 0.843557, 0.692108, 0.430069], 171.998239985708),
        ([0.780359, 0.459881, 0.999000, 0.943413], 2110.8327115596403),
        ([0.999000, 0.004212, 0.999000, 0.999000], 4399.056486577351),
        ([0.001000, 0.001000, 0.999000, 0.999000], 1599.957954631154),
        ([0.999000, 0.001000, 0.999000, 0.999000], 4399.055144422677),
        ([0.999000, 0.999000, 0.999000, 0.999000], 8585.271169822427),
        ([0.999000, 0.999000, 0.999000, 0.999000], 8585.271169822427),
        ([0.999000, 0.999000, 0.999000, 0.999000], 8585.271169822427),
        ([0.999000, 0.999000, 0.999000, 0.999000], 8585.271169822427),
        ([0.999000, 0.999000, 0.999000, 0.999000], 8585.271169822427),
        ([0.999000, 0.999000, 0.999000, 0.999000], 8585.271169822427),
        # Week 12: extra precision gave 8661!
        ([0.999990, 0.999990, 0.999990, 0.999990], 8661.707538429366),
    ],
    6: [
        ([0.464718, 0.242158, 0.574966, 0.999000, 0.001000], -0.6051709593412649),
        ([0.555523, 0.318405, 0.558469, 0.827090, 0.107716], -0.3236192232443728),
        ([0.503597, 0.321688, 0.644138, 0.679195, 0.083377], -0.24305027523553457),
        ([0.484159, 0.300684, 0.999000, 0.727665, 0.200197], -0.6463736098854705),
        ([0.485041, 0.319195, 0.441917, 0.673852, 0.001000], -0.4589568892389212),
        ([0.510213, 0.357301, 0.635921, 0.716988, 0.132412], -0.2887697320305941),
        ([0.535356, 0.148267, 0.676726, 0.673298, 0.001000], -0.5351446483272726),
        ([0.523208, 0.318104, 0.696794, 0.670420, 0.039495], -0.3599526840004564),
        ([0.437622, 0.287336, 0.517464, 0.687431, 0.102125], -0.26485097394144125),
        ([0.488603, 0.415065, 0.106767, 0.721757, 0.094505], -0.7104875634323662),
        ([0.483548, 0.319604, 0.600209, 0.691729, 0.102300], -0.1776416771496911),
        ([0.374307, 0.323687, 0.592309, 0.694541, 0.077659], -0.25090909622864077),
    ],
    7: [
        ([0.011667, 0.411792, 0.231071, 0.178655, 0.402625, 0.774073], 1.406973766148158),
        ([0.001000, 0.041205, 0.405612, 0.201364, 0.362883, 0.740672], 2.3196390727648777),
        ([0.001000, 0.001000, 0.453994, 0.144348, 0.363957, 0.798502], 1.8478394197874408),
        ([0.001000, 0.001000, 0.373894, 0.196300, 0.368172, 0.692343], 2.2682492009756166),
        ([0.001000, 0.052419, 0.525031, 0.238125, 0.349704, 0.746262], 2.4851090505166007),
        ([0.001000, 0.001000, 0.393790, 0.257389, 0.353881, 0.883435], 1.6722740195194474),
        ([0.001000, 0.001000, 0.819613, 0.291262, 0.326349, 0.725128], 1.72701846332078),
        ([0.001000, 0.039381, 0.491750, 0.256322, 0.349419, 0.715319], 2.590085737820418),
        ([0.001000, 0.059475, 0.483527, 0.285496, 0.350898, 0.708025], 2.6444110452302305),
        ([0.001000, 0.084080, 0.481882, 0.301159, 0.352549, 0.705487], 2.66593164693389),
        ([0.001000, 0.118807, 0.490150, 0.295966, 0.351695, 0.697299], 2.721698239546957),
        # Week 12: seventh consecutive improvement
        ([0.001000, 0.155046, 0.500688, 0.268011, 0.346739, 0.664377], 2.7912749553712453),
    ],
    8: [
        ([0.128571, 0.154552, 0.058784, 0.122456, 0.999000, 0.242869, 0.104295, 0.838426], 9.8724524063514),
        ([0.197340, 0.178658, 0.136725, 0.194275, 0.999000, 0.242783, 0.281984, 0.956694], 9.8660057167714),
        ([0.001000, 0.441264, 0.001000, 0.225180, 0.999000, 0.862045, 0.205110, 0.811789], 9.6845734856269),
        ([0.145845, 0.990589, 0.697497, 0.371990, 0.844860, 0.964908, 0.714317, 0.950307], 7.5153073992351),
        ([0.191968, 0.001000, 0.218895, 0.001000, 0.999000, 0.988239, 0.033429, 0.047593], 9.5707898443091),
        ([0.001000, 0.108710, 0.212514, 0.001000, 0.999000, 0.484524, 0.189084, 0.001214], 9.8799336632444),
        ([0.120027, 0.140849, 0.123494, 0.184973, 0.999000, 0.494865, 0.206437, 0.991719], 9.9625098872449),
        ([0.111594, 0.121843, 0.117425, 0.219912, 0.999000, 0.501740, 0.205869, 0.998881], 9.9577932389219),
        ([0.120192, 0.141524, 0.122869, 0.186698, 0.999000, 0.496741, 0.205722, 0.693429], 9.9768639255559),
        ([0.127059, 0.145678, 0.122260, 0.183354, 0.999000, 0.503249, 0.206190, 0.637361], 9.9771974566049),
        ([0.134606, 0.150351, 0.121936, 0.175139, 0.999000, 0.508081, 0.207165, 0.961018], 9.9637757960746),
        ([0.130021, 0.147430, 0.122008, 0.181514, 0.999000, 0.505876, 0.206593, 0.799056], 9.9731218340424),
    ],
}

# %% [markdown]
# ## Generate queries

# %%
results = generate_all_queries(new_data, FUNCTION_CONFIG, BASE_PATH)
# Out:
# ...
# F1 (2D) | 22 pts | gp_ucb | best=3.7202e-02
#   best input: [0.438746 0.45194 ]
# ...
#   UCB (κ=0.5) | mean=3.6728e-02 std=1.8681e-03
#   >>> 0.438520-0.451883
#
# ...
# F2 (2D) | 22 pts | ensemble | best=7.6236e-01
#   best input: [0.689878 0.999   ]
# ...
#   Ensemble candidates:
#     UCB      → mean=6.1626e-01 at [0.691 0.999]
#     EI       → mean=2.7918e-01 at [0.001 0.999]
#     CMA-ES   → mean=6.1626e-01 at [0.691 0.999]
#   WINNER: CMA-ES | mean=6.1626e-01 std=2.9687e-02
#   >>> 0.690599-0.999000
#
# ...
# F3 (3D) | 27 pts | ensemble | best=-7.7562e-03
#   best input: [0.001008 0.518377 0.396576]
# ...
#   Ensemble candidates:
#     UCB      → mean=-8.3234e-03 at [0.001 0.52  0.397]
#     EI       → mean=-5.2759e-02 at [0.002 0.999 0.499]
#     CMA-ES   → mean=-7.7573e-03 at [0.001 0.518 0.397]
#   WINNER: CMA-ES | mean=-7.7573e-03 std=7.2060e-05
#   >>> 0.001008-0.518377-0.396576
#
# ...
# F4 (4D) | 42 pts | gp_ucb | best=5.6290e-01
#   best input: [0.414523 0.394192 0.364468 0.429596]
# ...

# %%
## Polynomial diagnostics — cross-check GP predictions

from bbo.diagnostics import run_diagnostics
from bbo.data import load_function_data
import numpy as np

print("="*65)
print("  POLYNOMIAL DIAGNOSTIC — does it agree with GP?")
print("="*65)

for i in range(1, 9):
    inputs, outputs = load_function_data(i, new_data, BASE_PATH)
    best_idx = np.argmax(outputs)
    run_diagnostics(inputs, outputs, inputs.shape[1], i, inputs[best_idx])
# Out:
# ...
#   POLYNOMIAL DIAGNOSTIC — does it agree with GP?
# ...
#   F1 poly(deg=3): R²=0.413 | max=1.7572e-02 at [0.397 0.462] | dist from GP best=0.043 | AGREE
#   F2 poly(deg=3): R²=0.634 | max=6.5032e-01 at [0.417 0.999] | dist from GP best=0.273 | SLIGHT DISAGREEMENT
#   F3 poly(deg=2): R²=0.553 | max=-5.3263e-02 at [0.001 0.613 0.136] | dist from GP best=0.277 | SLIGHT DISAGREEMENT
#   F4 poly(deg=2): R²=0.918 | max=-1.8876e+00 at [0.288 0.303 0.26  0.271] | dist from GP best=0.246 | SLIGHT DISAGREEMENT
#   F5 poly(deg=2): R²=0.970 | max=8.2430e+03 at [0.999 0.999 0.999 0.999] | dist from GP best=0.002 | AGREE
#   F6 poly(deg=2): R²=0.952 | max=-1.3481e-01 at [0.159 0.076 0.586 0.982 0.002] | dist from GP best=0.509 | DISAGREE — worth investigating
#   F7 poly(deg=2): R²=0.885 | max=2.7592e+00 at [0.028 0.007 0.673 0.036 0.035 0.995] | dist from GP best=0.559 | DISAGREE — worth investigating
# ...

# %% [markdown]
# ## Inspect data (optional)

# %%
from bbo.data import load_function_data
import numpy as np
import os

for i in range(1, 9):
    inputs, outputs = load_function_data(i, new_data, BASE_PATH)
    best_idx = np.argmax(outputs)
    n_new = len(new_data.get(i, []))
    
    # Check improvement over initial data
    folder = os.path.join(BASE_PATH, f"function_{i}")
    orig_best = np.load(os.path.join(folder, "initial_outputs.npy")).max()
    improved = outputs[best_idx] > orig_best
    
    print(f"F{i} ({inputs.shape[1]}D) | {inputs.shape[0]} pts ({n_new} new) | "
          f"best={outputs[best_idx]:.4e} | "
          f"{'IMPROVED' if improved else 'no improvement'} from {orig_best:.4e}")
# Out:
# F1 (2D) | 22 pts (12 new) | best=3.7202e-02 | IMPROVED from 7.7109e-16
# F2 (2D) | 22 pts (12 new) | best=7.6236e-01 | IMPROVED from 6.1121e-01
# F3 (3D) | 27 pts (12 new) | best=-7.7562e-03 | IMPROVED from -3.4835e-02
# F4 (4D) | 42 pts (12 new) | best=5.6290e-01 | IMPROVED from -4.0255e+00
# F5 (4D) | 32 pts (12 new) | best=8.6617e+03 | IMPROVED from 1.0889e+03
# F6 (5D) | 32 pts (12 new) | best=-1.7764e-01 | IMPROVED from -7.1426e-01
# F7 (6D) | 42 pts (12 new) | best=2.7913e+00 | IMPROVED from 1.3650e+00
# F8 (8D) | 52 pts (12 new) | best=9.9772e+00 | IMPROVED from 9.5985e+00
